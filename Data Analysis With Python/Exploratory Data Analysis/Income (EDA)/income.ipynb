# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv('income_evaluation.csv')
df.drop_duplicates(inplace=True)
df.describe()
# Out:
#                 age        fnlwgt   education-num   capital-gain  \
# count  32537.000000  3.253700e+04    32537.000000   32537.000000
# mean      38.585549  1.897808e+05       10.081815    1078.443741
# std       13.637984  1.055565e+05        2.571633    7387.957424
# min       17.000000  1.228500e+04        1.000000       0.000000
# 25%       28.000000  1.178270e+05        9.000000       0.000000
# 50%       37.000000  1.783560e+05       10.000000       0.000000
# 75%       48.000000  2.369930e+05       12.000000       0.000000
# max       90.000000  1.484705e+06       16.000000   99999.000000
#
#         capital-loss   hours-per-week
# count   32537.000000     32537.000000
# mean       87.368227        40.440329
# std       403.101833        12.346889
# min         0.000000         1.000000
# 25%         0.000000        40.000000
# 50%         0.000000        40.000000
# 75%         0.000000        45.000000
# max      4356.000000        99.000000

# %%
df[" workclass"].value_counts().sort_values(ascending=False).plot(kind='bar')
plt.title('Distribution of Workclass')
plt.show()

# %%
df[" income"].value_counts().sort_values(ascending=True).plot(kind='bar')
plt.title('Distribution of Income')
plt.show()

# %%
df[" education"].value_counts().plot(kind='bar')
plt.title('Distribution of Education')
plt.show()

# %%
df.isna().sum()
# Out:
# age                0
#  workclass         0
#  fnlwgt            0
#  education         0
#  education-num     0
#  marital-status    0
#  occupation        0
#  relationship      0
#  race              0
#  sex               0
#  capital-gain      0
#  capital-loss      0
#  hours-per-week    0
#  native-country    0
#  income            0
# dtype: int64
